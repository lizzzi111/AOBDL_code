# %%
# GOOGLE COLAB SETUP

# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os 
os.chdir('/content/drive/My Drive/Colab Notebooks/adaptHAN/AOBDL_code')

# %%
# !git clone github.com/lizzzi111/AOBDL_code.git
# Out:
# Cloning into 'AOBDL_code'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (3/3), done.

# %%
# !git config --global user.name "lizzzi111"
# !git config --global user.email "zinovyee@gmail.com"

# %%
# !git add -A

# %%
# !git commit -m 'added codes'
# Out:
# [master c9d8ef1] added codes
#  14 files changed, 625481 insertions(+)
#  create mode 100644 codes/Copy of code_2_TML_DL.ipynb
#  create mode 100644 codes/Settings.ipynb
#  create mode 100644 codes/code_1_preparation.ipynb
#  create mode 100644 codes/code_2_TML_DL.ipynb
#  create mode 100644 codes/deprecated_code_2_TCNN.ipynb
#  create mode 100644 data/test_labelled_cleaned_no_punkt.csv
#  create mode 100644 data/test_labelled_cleaned_sent_punkt.csv
#  create mode 100644 data/test_unlabelled_cleaned_no_punkt.csv
#  create mode 100644 data/test_unlabelled_cleaned_sent_punkt.csv
#  create mode 100644 data/train_cleaned_no_punkt.csv
#  create mode 100644 data/train_cleaned_sent_punkt.csv
#  create mode 100644 raw_data/test.csv.zip
#  create mode 100644 raw_data/test_labels.csv.zip
#  create mode 100644 raw_data/train.csv.zip

# %%
# !git push https://lizzzi111:proga111@github.com/lizzzi111/AOBDL_code.git
# Out:
# ^C

# %%
# !git pull https://lizzzi111:proga111@github.com/lizzzi111/AOBDL_code.git
# Out:
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 4 (delta 1), reused 4 (delta 1), pack-reused 0
# Unpacking objects: 100% (4/4), done.
# From https://github.com/lizzzi111/AOBDL_code
#  * branch            HEAD       -> FETCH_HEAD
# Updating c9d8ef1..d859ced
# Fast-forward
#  codes/code_2_TML_DL.ipynb | 1005 ++++++++++++++++++++++++++++++++++++++++++++-
#  1 file changed, 1004 insertions(+), 1 deletion(-)
